# %%
from libs.io_analyzer import IOTableAnalyzer

analyzer = IOTableAnalyzer()
# Out:
# Loading I-O Table data...
# Loaded 411 sectors from basicmap sheet
# Loaded A (direct) coefficient matrix: (384, 380)
# Loaded Am (import) coefficient matrix: (380, 380)
# Loaded Ad (domestic) coefficient matrix: (380, 380)
# Loaded indirect production coefficient matrix: (380, 380)
# Loaded indirect import coefficient matrix: (380, 380)
# Loaded value-added coefficient matrix: (380, 380)
# Loaded job coefficient matrix: (165, 165)
# Loaded direct employment coefficient matrix: (165, 165)
# Loaded codemap with 411 sector mappings
# Loaded subsectormap with 196 sub-sector names
# Created sub-sector-to-name mapping for 196 sub-sectors
# Created basic-to-subsector mapping for 411 sectors
# Data loading complete!

# %%
analyzer.load_damageshock_data()
# Out:
# Loaded damageshock data: (15, 32)

# %%
df = analyzer.damageshock_data
df.head()
# Out:
#                   내역                   출처  ...          2049          2050
# 0            석탄사용감소량               PLANiT  ...  0.000000e+00  0.000000e+00
# 1         재생에너지전력사용량                  NaN  ...  8.525312e+10  8.525312e+10
# 2    부생가스전력->재생전력 전환  POSCO ESG factbook   ...  8.024892e+10  8.024892e+10
# 3             전기로 전력               PLANiT  ...  5.004203e+09  5.004203e+09
# 4              수소사용량               PLANiT  ...  4.310000e+08  4.310000e+08
#
# [5 rows x 32 columns]
